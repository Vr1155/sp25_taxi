# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import sys
import os

# Add the parent directory to the Python path
sys.path.append(os.path.abspath(os.path.join(os.getcwd(), "..")))

# %%
import pandas as pd

from src.config import TRANSFORMED_DATA_DIR

features_and_targets = pd.read_parquet(TRANSFORMED_DATA_DIR / "tabular_data.parquet")

# %%
features = features_and_targets.iloc[:, :-1]
targets = features_and_targets["target"]

# %%
# features[features['location_id']==43]
features[features['pickup_location_id']==43]
# Out:
#        rides_t-672  rides_t-671  rides_t-670  rides_t-669  rides_t-668  \
# 13817           92           81           29           15            4
# 13818            2            0            2            2            0
# 13819            1            0            0            0            1
# 13820            3            2            0            0            1
# 13821            6            0            0            1            0
# ...            ...          ...          ...          ...          ...
# 14149            3            0            1            0            1
# 14150            6            2            2            0            1
# 14151           20            7            2            0            3
# 14152           10            8            3            1            3
# 14153           19           10            1            2            2
#
#        rides_t-667  rides_t-666  rides_t-665  rides_t-664  rides_t-663  ...  \
# 13817            4            3           12           12           23  ...
# 13818            1            5           10           16           29  ...
# 13819            4           17           49           54           52  ...
# 13820            1           11           51           50           60  ...
# 13821            2           10           61           62           66  ...
# ...            ...          ...          ...          ...          ...  ...
# 14149            6           13           54          106           83  ...
# 14150            7            8           58           84           90  ...
# 14151            3           13           54           67           90  ...
# 14152            0            8           19           35           67  ...
# 14153            3            2           23           28           64  ...
#
#        rides_t-8  rides_t-7  rides_t-6  rides_t-5  rides_t-4  rides_t-3  \
# 13817        227        198        114        149         98         42
# 13818        175         97         57         35         28         16
# 13819        145        104         99         74         50         33
# 13820        156        106         88         80         49         43
# 13821        138        112        103        103         78         56
# ...          ...        ...        ...        ...        ...        ...
# 14149        205        132         64         49         44         31
# 14150         97         57         73         29         48         42
# 14151        239        128         73         52         50         43
# 14152        200        185        160        133        158         69
# 14153        192        173        144        111        133         78
#
#        rides_t-2  rides_t-1  pickup_hour  pickup_location_id
# 13817         38         37   2023-01-29                  43
# 13818         17         10   2023-01-30                  43
# 13819         16         16   2023-01-31                  43
# 13820         34         13   2023-02-01                  43
# 13821         40         25   2023-02-02                  43
# ...          ...        ...          ...                 ...
# 14149         14         10   2023-12-27                  43
# 14150         24          7   2023-12-28                  43
# 14151         30         17   2023-12-29                  43
# 14152         33         19   2023-12-30                  43
# 14153         39         28   2023-12-31                  43
#
# [337 rows x 674 columns]

# %%
targets[14153]
# Out:
# 15

# %%
# Check the content of the features dataframe for the specified row_id
row_id = 14153
print(features.loc[row_id])
print(targets.loc[row_id])
# Out:
# rides_t-672                            19
# rides_t-671                            10
# rides_t-670                             1
# rides_t-669                             2
# rides_t-668                             2
#                              ...
# rides_t-3                              78
# rides_t-2                              39
# rides_t-1                              28
# pickup_hour           2023-12-31 00:00:00
# pickup_location_id                     43
# Name: 14153, Length: 674, dtype: object
# 15

# %%
from src.plot_utils import plot_aggregated_time_series

# plot_aggregated_time_series(features, targets, row_id=3772)

plot_aggregated_time_series(features, targets, row_id=14153)
